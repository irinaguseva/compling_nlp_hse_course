# %% [markdown]
# # Домашнее задание № 1

# %% [markdown]
# ## Задание 1 (2 балла)

# %% [markdown]
# Найдите 1 любой способ сломать токенизацию на предложения функцией sentenize из библиотеки razdel. Придумайте (или найдите на каком-то корпусе) такое предложение (или несколько предложений), которое будет некорректно разобрано sentenize, но при этом будет грамматически корректным.

# %%
# !pip install razdel

# %%
from razdel import sentenize

#text = "Обсудили вопросы: 1. Бюджет 2. Сроки 3. Персонал. После этого разошлись."
text = "Они купили кг. груш, а также кг. Антоновки. Ни он, ни др. Антоны не хотели этого. Об этом давным давно говорил ув. Максим, который нам всем так понравился. "
result = list(sentenize(text))
print(result)
for sent in result:
    print(sent.text)

# [Substring(0, 32, 'Они купили кг. груш, а также кг.'), Substring(33, 43, 'Антоновки.'), Substring(44, 57, 'Ни он, ни др.'), Substring(58, 81, 'Антоны не хотели этого.'), Substring(82, 114, 'Об этом давным давно говорил ув.'), Substring(115, 155, 'Максим, который нам всем так понравился.')]
# Они купили кг. груш, а также кг.
# Антоновки.
# Ни он, ни др.
# Антоны не хотели этого.
# Об этом давным давно говорил ув.
# Максим, который нам всем так понравился.
# Out:
# [Substring(0, 32, 'Они купили кг. груш, а также кг.'), Substring(33, 43, 'Антоновки.'), Substring(44, 57, 'Ни он, ни др.'), Substring(58, 81, 'Антоны не хотели этого.'), Substring(82, 114, 'Об этом давным давно говорил ув.'), Substring(115, 155, 'Максим, который нам всем так понравился.')]
# Они купили кг. груш, а также кг.
# Антоновки.
# Ни он, ни др.
# Антоны не хотели этого.
# Об этом давным давно говорил ув.
# Максим, который нам всем так понравился.

# %% [markdown]
# ## 2. Токенизация Mystem vs razdel.tokenize (2 балла)
#
#
# Токенизируйте текст с помощью razdel и с помощью Mystem. Найдите различия в токенизациях. Что по вашему работает лучше на приведенном тексте?

# %%
text_dwarfs = """
Вторым и третьим открытыми белыми карликами стали Сириус B и Процион B. В 1844 году директор Кёнигсбергской обсерватории Фридрих Бессель, анализируя данные наблюдений, которые велись с 1755 года, обнаружил, что Сириус, ярчайшая звезда земного неба, и Процион периодически, хотя и весьма слабо, отклоняются от прямолинейной траектории движения по небесной сфере[5]. Бессель пришёл к выводу, что у каждой из них должен быть близкий спутник. Сообщение было встречено скептически, поскольку слабый спутник оставался ненаблюдаемым, а его масса должна была быть достаточно велика — сравнимой с массой Сириуса и Проциона, соответственно.

В январе 1862 года Элвин Грэхэм Кларк, юстируя 18-дюймовый рефрактор, самый большой на то время телескоп в мире (Dearborn Telescope), впоследствии поставленный семейной фирмой Кларков в обсерваторию Чикагского университета, обнаружил в непосредственной близости от Сириуса тусклую звёздочку. Это был спутник Сириуса, Сириус B, предсказанный Бесселем[6]. А в 1896 году американский астроном Д. М. Шеберле открыл Процион B, подтвердив тем самым и второе предсказание Бесселя.

В 1915 году американский астроном Уолтер Сидней Адамс измерил спектр Сириуса B. Из измерений следовало, что его температура не ниже, чем у Сириуса A (по современным данным, температура поверхности Сириуса B составляет 25 000 K, а Сириуса A — 10 000 К), что, с учётом его в 10 000 раз меньшей, чем у Сириуса A, светимости указывает на очень малый радиус и, соответственно, высокую плотность — 106 г/см3 (плотность Сириуса ~0,25 г/см3, плотность Солнца ~1,4 г/см3).
"""

# %%
# !pip install pymystem3

# %%
import razdel
from pymystem3 import Mystem

def tokenize_with_razdel(text):
    tokens = [token.text for token in razdel.tokenize(text)]
    return tokens

def tokenize_with_mystem(text):
    mystem = Mystem()
    tokens = mystem.analyze(text)
    result = []
    for token in tokens:
        result.append(token['text'])
    return [token for token in result if token.strip()]

# %%
list(tokenize_with_razdel(text_dwarfs))
# Out:
# ['Вторым',
#  'и',
#  'третьим',
#  'открытыми',
#  'белыми',
#  'карликами',
#  'стали',
#  'Сириус',
#  'B',
#  'и',
#  'Процион',
#  'B',
#  '.',
#  'В',
#  '1844',
#  'году',
#  'директор',
#  'Кёнигсбергской',
#  'обсерватории',
#  'Фридрих',
#  'Бессель',
#  ',',
#  'анализируя',
#  'данные',
#  'наблюдений',
#  ',',
#  'которые',
#  'велись',
#  'с',
#  '1755',
#  'года',
#  ',',
#  'обнаружил',
#  ',',
#  'что',
#  'Сириус',
#  ',',
#  'ярчайшая',
#  'звезда',
#  'земного',
#  'неба',
#  ',',
#  'и',
#  'Процион',
#  'периодически',
#  ',',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ',',
#  'отклоняются',
#  'от',
#  'прямолинейной',
#  'траектории',
#  'движения',
#  'по',
#  'небесной',
#  'сфере',
#  '[',
#  '5',
#  ']',
#  '.',
#  'Бессель',
#  'пришёл',
#  'к',
#  'выводу',
#  ',',
#  'что',
#  'у',
#  'каждой',
#  'из',
#  'них',
#  'должен',
#  'быть',
#  'близкий',
#  'спутник',
#  '.',
#  'Сообщение',
#  'было',
#  'встречено',
#  'скептически',
#  ',',
# ...

# %%
list(tokenize_with_mystem(text_dwarfs))
# Out:
# ['Вторым',
#  'и',
#  'третьим',
#  'открытыми',
#  'белыми',
#  'карликами',
#  'стали',
#  'Сириус',
#  'B',
#  'и',
#  'Процион',
#  'B',
#  '. ',
#  'В',
#  '1844',
#  'году',
#  'директор',
#  'Кёнигсбергской',
#  'обсерватории',
#  'Фридрих',
#  'Бессель',
#  ', ',
#  'анализируя',
#  'данные',
#  'наблюдений',
#  ', ',
#  'которые',
#  'велись',
#  'с',
#  '1755',
#  'года',
#  ', ',
#  'обнаружил',
#  ', ',
#  'что',
#  'Сириус',
#  ', ',
#  'ярчайшая',
#  'звезда',
#  'земного',
#  'неба',
#  ', ',
#  'и',
#  'Процион',
#  'периодически',
#  ', ',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ', ',
#  'отклоняются',
#  'от',
#  'прямолинейной',
#  'траектории',
#  'движения',
#  'по',
#  'небесной',
#  'сфере',
#  '[',
#  '5',
#  ']',
#  '. ',
#  'Бессель',
#  'пришёл',
#  'к',
#  'выводу',
#  ', ',
#  'что',
#  'у',
#  'каждой',
#  'из',
#  'них',
#  'должен',
#  'быть',
#  'близкий',
#  'спутник',
#  '. ',
#  'Сообщение',
#  'было',
#  'встречено',
#  'скептически',
# ...

# %%
def compare_tokenizations(text):
    """Сравнение двух токенизаций"""
    razdel_tokens = tokenize_with_razdel(text)
    mystem_tokens = tokenize_with_mystem(text)

    print("=== RAZDEL ТОКЕНИЗАЦИЯ ===")
    print(f"Количество токенов: {len(razdel_tokens)}")
    print("Первые 30 токенов:", razdel_tokens[:30])
    print()

    print("=== MYSTEM ТОКЕНИЗАЦИЯ ===")
    print(f"Количество токенов: {len(mystem_tokens)}")
    print("Первые 30 токенов:", mystem_tokens[:30])
    print()

    # Находим различия
    razdel_set = set(razdel_tokens)
    mystem_set = set(mystem_tokens)

    print("=== РАЗЛИЧИЯ ===")
    print("Токены только в razdel:", razdel_set - mystem_set)
    print("Токены только в mystem:", mystem_set - razdel_set)
    print()

    # Сравнение длин
    print(f"Razdel tokens: {len(razdel_tokens)}")
    print(f"Mystem tokens: {len(mystem_tokens)}")
    print()

    print("=== РЕЗУЛЬТАТ ===")
    print(f"Razdel tokens: {razdel_tokens}")
    print()
    print()
    print(f"Mystem tokens: {mystem_tokens}")

# %%
compare_tokenizations(text_dwarfs)
# Out:
# === RAZDEL ТОКЕНИЗАЦИЯ ===
# Количество токенов: 292
# Первые 30 токенов: ['Вторым', 'и', 'третьим', 'открытыми', 'белыми', 'карликами', 'стали', 'Сириус', 'B', 'и', 'Процион', 'B', '.', 'В', '1844', 'году', 'директор', 'Кёнигсбергской', 'обсерватории', 'Фридрих', 'Бессель', ',', 'анализируя', 'данные', 'наблюдений', ',', 'которые', 'велись', 'с', '1755']
#
# === MYSTEM ТОКЕНИЗАЦИЯ ===
# Количество токенов: 293
# Первые 30 токенов: ['Вторым', 'и', 'третьим', 'открытыми', 'белыми', 'карликами', 'стали', 'Сириус', 'B', 'и', 'Процион', 'B', '. ', 'В', '1844', 'году', 'директор', 'Кёнигсбергской', 'обсерватории', 'Фридрих', 'Бессель', ', ', 'анализируя', 'данные', 'наблюдений', ', ', 'которые', 'велись', 'с', '1755']
#
# === РАЗЛИЧИЯ ===
# Токены только в razdel: {'0,25', 'см', '3', '—', '~', '18-дюймовый', '(', '1,4'}
# Токены только в mystem: {'), ', 'см3', ' (', 'дюймовый', '0', '. ', '18', ' — ', '1', '-', ', ', '4', ' ~'}
#
# Razdel tokens: 292
# Mystem tokens: 293
#
# ...

# %% [markdown]
# Наблюдения из полученного:
#
# *   razdel более грамотно справился с токенизацией в следующих случаях: '0,25', '18-дюймовый', '1,4'
# *   mystem оказался лучше в выделении "см3" в качестве отдельного токена

# %% [markdown]
# ## 3. Лемматизация Mystem vs Pymorphy (2 балла)

# %% [markdown]
# Лемматизируйте текст с помощью mystem и pymorphy. Найдите различия в лемматизации. Что по вашему работает лучше на приведенном тексте?

# %% [markdown]
# Важно: для пайморфи используйте токенизацию из mystem, чтобы исключить влияние токенизации на результат. Анализируйте только значимые различия, а не технические особенности (не сравнивайте скорость работы и удобность интерфейса).
#
# В майстеме убедитесь, что используется дизамбигуация.

# %%
from pymystem3 import Mystem
import re

def lemmatize_with_mystem(text):

    mystem = Mystem(disambiguation=True)
    result = mystem.analyze(text)

    tokens = []
    for token in result:
        if 'analysis' in token and token['analysis']:
            lemma = token['analysis'][0]['lex']
            tokens.append(lemma)
        elif 'text' in token and token['text'].strip():
            tokens.append(token['text'])

    return [item for item in tokens]

# %%
# !pip install pymorphy3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 83.2 MB/s eta 0:00:00
# ...

# %%
from pymorphy3 import MorphAnalyzer

morph = MorphAnalyzer()

# Функция для лемматизации списка токенов
def lemmatize_with_pymorphy3(token_list):
    lemmas = []
    for token in token_list:
        # Получаем первый (наиболее вероятный) разбор слова
        parsed = morph.parse(token)[0]
        # Извлекаем нормальную форму (лемму)
        lemma = parsed.normal_form
        lemmas.append(lemma)
    return lemmas

# %%
tokens = tokenize_with_mystem(text_dwarfs)

lemmatized_tokens_mystem = lemmatize_with_mystem(text_dwarfs)

# Лемматизация с помощью pymorphy на тех же токенах
lemmatized_tokens_pymorphy = lemmatize_with_pymorphy3(tokens)

# %%
tokens
# Out:
# ['Вторым',
#  'и',
#  'третьим',
#  'открытыми',
#  'белыми',
#  'карликами',
#  'стали',
#  'Сириус',
#  'B',
#  'и',
#  'Процион',
#  'B',
#  '. ',
#  'В',
#  '1844',
#  'году',
#  'директор',
#  'Кёнигсбергской',
#  'обсерватории',
#  'Фридрих',
#  'Бессель',
#  ', ',
#  'анализируя',
#  'данные',
#  'наблюдений',
#  ', ',
#  'которые',
#  'велись',
#  'с',
#  '1755',
#  'года',
#  ', ',
#  'обнаружил',
#  ', ',
#  'что',
#  'Сириус',
#  ', ',
#  'ярчайшая',
#  'звезда',
#  'земного',
#  'неба',
#  ', ',
#  'и',
#  'Процион',
#  'периодически',
#  ', ',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ', ',
#  'отклоняются',
#  'от',
#  'прямолинейной',
#  'траектории',
#  'движения',
#  'по',
#  'небесной',
#  'сфере',
#  '[',
#  '5',
#  ']',
#  '. ',
#  'Бессель',
#  'пришёл',
#  'к',
#  'выводу',
#  ', ',
#  'что',
#  'у',
#  'каждой',
#  'из',
#  'них',
#  'должен',
#  'быть',
#  'близкий',
#  'спутник',
#  '. ',
#  'Сообщение',
#  'было',
#  'встречено',
#  'скептически',
# ...

# %%
lemmatized_tokens_mystem
# Out:
# ['второй',
#  'и',
#  'третий',
#  'открытый',
#  'белый',
#  'карлик',
#  'становиться',
#  'сириус',
#  'B',
#  'и',
#  'процион',
#  'B',
#  '. ',
#  'в',
#  '1844',
#  'год',
#  'директор',
#  'кенигсбергский',
#  'обсерватория',
#  'фридрих',
#  'бессель',
#  ', ',
#  'анализировать',
#  'данные',
#  'наблюдение',
#  ', ',
#  'который',
#  'вестись',
#  'с',
#  '1755',
#  'год',
#  ', ',
#  'обнаруживать',
#  ', ',
#  'что',
#  'сириус',
#  ', ',
#  'яркий',
#  'звезда',
#  'земной',
#  'небо',
#  ', ',
#  'и',
#  'процион',
#  'периодически',
#  ', ',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ', ',
#  'отклоняться',
#  'от',
#  'прямолинейный',
#  'траектория',
#  'движение',
#  'по',
#  'небесный',
#  'сфера',
#  '[',
#  '5',
#  ']',
#  '. ',
#  'бессель',
#  'приходить',
#  'к',
#  'вывод',
#  ', ',
#  'что',
#  'у',
#  'каждый',
#  'из',
#  'они',
#  'должный',
#  'быть',
#  'близкий',
#  'спутник',
#  '. ',
#  'сообщение',
#  'быть',
#  'встречать',
#  'скептически',
# ...

# %%
lemmatized_tokens_pymorphy
# Out:
# ['второй',
#  'и',
#  'третий',
#  'открытый',
#  'белый',
#  'карлик',
#  'стать',
#  'сириус',
#  'b',
#  'и',
#  'процион',
#  'b',
#  '. ',
#  'в',
#  '1844',
#  'год',
#  'директор',
#  'кёнигсбергский',
#  'обсерватория',
#  'фридрих',
#  'бессель',
#  ', ',
#  'анализировать',
#  'дать',
#  'наблюдение',
#  ', ',
#  'который',
#  'вестись',
#  'с',
#  '1755',
#  'год',
#  ', ',
#  'обнаружить',
#  ', ',
#  'что',
#  'сириус',
#  ', ',
#  'яркий',
#  'звезда',
#  'земной',
#  'небо',
#  ', ',
#  'и',
#  'процион',
#  'периодически',
#  ', ',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ', ',
#  'отклоняться',
#  'от',
#  'прямолинейный',
#  'траектория',
#  'движение',
#  'по',
#  'небесный',
#  'сфера',
#  '[',
#  '5',
#  ']',
#  '. ',
#  'бессель',
#  'прийти',
#  'к',
#  'вывод',
#  ', ',
#  'что',
#  'у',
#  'каждый',
#  'из',
#  'они',
#  'должный',
#  'быть',
#  'близкий',
#  'спутник',
#  '. ',
#  'сообщение',
#  'быть',
#  'встретить',
#  'скептически',
#  ', ',
# ...

# %%
def compare_lemmatizations(text):
    """Сравнение двух лемматизаций"""
    tokens = tokenize_with_mystem(text_dwarfs)

    # Лемматизация с помощью mystem на тех же токенах
    lemmatized_tokens_mystem = lemmatize_with_mystem(text_dwarfs)

    # Лемматизация с помощью pymorphy на тех же токенах
    lemmatized_tokens_pymorphy = lemmatize_with_pymorphy3(tokens)

    print("=== PYMORPHY ЛЕММАТИЗАЦИЯ ===")
    print(f"Количество лемм: {len(lemmatized_tokens_pymorphy)}")
    print("Первые 30 лемм:", lemmatized_tokens_pymorphy[:30])
    print()

    print("=== MYSTEM ТОКЕНИЗАЦИЯ ===")
    print(f"Количество токенов: {len(lemmatized_tokens_mystem)}")
    print("Первые 30 токенов:", lemmatized_tokens_mystem[:30])
    print()

    # Находим различия
    pymorphy_set = set(lemmatized_tokens_pymorphy)
    mystem_set = set(lemmatized_tokens_mystem)

    print("=== РАЗЛИЧИЯ ===")
    print("Токены только в pymorphy:", pymorphy_set - mystem_set)
    print("Токены только в mystem:", mystem_set - pymorphy_set)
    print()

    # Сравнение длин
    print(f"pymorphy tokens: {len(lemmatized_tokens_pymorphy)}")
    print(f"Mystem tokens: {len(lemmatized_tokens_mystem)}")
    print()

    print("=== РЕЗУЛЬТАТ ===")
    print(f"pymorphy tokens: {lemmatized_tokens_pymorphy}")
    print()
    print()
    print(f"Mystem tokens: {lemmatized_tokens_mystem}")

# %%
compare_lemmatizations(text_dwarfs)
# Out:
# === PYMORPHY ЛЕММАТИЗАЦИЯ ===
# Количество лемм: 293
# Первые 30 лемм: ['второй', 'и', 'третий', 'открытый', 'белый', 'карлик', 'стать', 'сириус', 'b', 'и', 'процион', 'b', '. ', 'в', '1844', 'год', 'директор', 'кёнигсбергский', 'обсерватория', 'фридрих', 'бессель', ', ', 'анализировать', 'дать', 'наблюдение', ', ', 'который', 'вестись', 'с', '1755']
#
# === MYSTEM ТОКЕНИЗАЦИЯ ===
# Количество токенов: 293
# Первые 30 токенов: ['второй', 'и', 'третий', 'открытый', 'белый', 'карлик', 'становиться', 'сириус', 'B', 'и', 'процион', 'B', '. ', 'в', '1844', 'год', 'директор', 'кенигсбергский', 'обсерватория', 'фридрих', 'бессель', ', ', 'анализировать', 'данные', 'наблюдение', ', ', 'который', 'вестись', 'с', '1755']
#
# === РАЗЛИЧИЯ ===
# ...

# %% [markdown]
# Вариант леммы "обнаружить" для "обнаружил" от pymorphy считаю более корректным, нежели "обнаруживать" от mystem. В целом для pymorphy более свойственно приведение к глаголу совершенного вида.

# %% [markdown]
# ## 4. Лемматизация в SpaCy (2 балла)
#
# С помощью Spacy (модель для русского языка) лемматизируйте тот же текст. Проверьте есть ли различия с Mystem и Pymoprhy.

# %%
# !pip install spacy

# %%
# !python -m spacy download ru_core_news_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 MB 19.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Загрузка модели для русского языка
nlp = spacy.load("ru_core_news_md")

# %%
doc = nlp(text_dwarfs)

# Лемматизация и создание списка лемм
lemmatized_tokens_spacy = [token.lemma_ for token in doc]

# %%
lemmatized_tokens_spacy
# Out:
# ['\n',
#  'второй',
#  'и',
#  'третий',
#  'открытый',
#  'белый',
#  'карлик',
#  'стать',
#  'сириус',
#  'b',
#  'и',
#  'процион',
#  'b.',
#  'в',
#  '1844',
#  'год',
#  'директор',
#  'кёнигсбергский',
#  'обсерватория',
#  'фридрих',
#  'бессель',
#  ',',
#  'анализировать',
#  'данные',
#  'наблюдение',
#  ',',
#  'которые',
#  'вестись',
#  'с',
#  '1755',
#  'год',
#  ',',
#  'обнаружить',
#  ',',
#  'что',
#  'сириус',
#  ',',
#  'яркий',
#  'звезда',
#  'земной',
#  'небо',
#  ',',
#  'и',
#  'процион',
#  'периодически',
#  ',',
#  'хотя',
#  'и',
#  'весьма',
#  'слабо',
#  ',',
#  'отклоняться',
#  'от',
#  'прямолинейный',
#  'траектория',
#  'движение',
#  'по',
#  'небесный',
#  'сфере[5',
#  ']',
#  '.',
#  'бессель',
#  'прийти',
#  'к',
#  'вывод',
#  ',',
#  'что',
#  'у',
#  'каждый',
#  'из',
#  'них',
#  'должный',
#  'быть',
#  'близкий',
#  'спутник',
#  '.',
#  'сообщение',
#  'было',
#  'встретить',
#  'скептически',
#  ',',
#  'поскольку',
# ...

# %% [markdown]
# spacy также имеет тенденцию к приведению глаголов к лемме совершенного времени, но вместе с тем присутствуют и леммы несовершенного вида. На мой взгляд, дает более сбалансированнвй результат.

# %% [markdown]
# ## 5*. LSH (2 балла)

# %% [markdown]
# *необязательное задание чтобы получить 10 баллов
#
# Попробуйте искать дубликаты в настоящих текстах. Например, можете взять https://github.com/mannefedov/compling_nlp_hse_course/blob/master/data/anna_karenina.txt или https://github.com/mannefedov/compling_nlp_hse_course/blob/master/data/besy_dostoevsky.txt (или любой другой корпус)
#
# Используйте код из семинара для нахождения кандидатов в дубликаты (шинглы -> минхэш - lsh) и рассчитайте реальную меру Жаккара между полученными кандидатами. Настройте параметры k, num_hash_functions, bands так чтобы результаты получались адекватные (мера Жаккара хотя бы больше нуля).
#
# (Можете взять 500-1000 текстов если весь корпус обрабатывается слишком долго)

# %%
# ваш код
